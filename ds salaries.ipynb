# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv('ds_salaries.csv')
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count   607.000000  6.070000e+02     607.000000     607.00000
# mean   2021.405272  3.240001e+05  112297.869852      70.92257
# std       0.692133  1.544357e+06   70957.259411      40.70913
# min    2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000
# max    2022.000000  3.040000e+07  600000.000000     100.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
plt.bar(data.groupby('work_year').count().index, data.groupby('work_year').count()['job_title'])
plt.xticks(data.groupby('work_year').count().index)
plt.title('Work Year')
# Out:
# Text(0.5, 1.0, 'Work Year')

# %%
plt.bar(data.groupby('experience_level').count().index, data.groupby('experience_level').count()['job_title'])
plt.xticks(data.groupby('experience_level').count().index)
plt.title('Experience Level')
# Out:
# Text(0.5, 1.0, 'Experience Level')

# %%
plt.figure(figsize=[10,6])

plt.bar(data.groupby('salary_currency').count().index, data.groupby('salary_currency').count()['work_year'])
plt.xticks(data.groupby('salary_currency').count().index)
plt.title('Salary Currency')
# Out:
# Text(0.5, 1.0, 'Salary Currency')

# %%
plt.figure(figsize=[10,6])

plt.bar(data.groupby('company_size').count().index, data.groupby('company_size').count()['work_year'])
plt.xticks(data.groupby('company_size').count().index)
plt.title('Salary Currency')
# Out:
# Text(0.5, 1.0, 'Salary Currency')

# %% [markdown]
# ## Bivariative

# %%
plt.figure(figsize=([8,14]))

sns.boxplot(x='salary_in_usd', y='job_title', data=data)
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='job_title'>

# %%
data_el_Wy = data[['experience_level','work_year']].value_counts(sort=False).unstack()
data_el_Wy.plot(kind='bar', figsize=[10,6])
# Out:
# <AxesSubplot:xlabel='experience_level'>

# %%
data_et_wy = data[['employment_type','work_year']].value_counts(sort=False).unstack()
data_et_wy.plot(kind='bar', figsize=[10,6])
# Out:
# <AxesSubplot:xlabel='employment_type'>

# %%
data_cs_wy = data[['company_size','work_year']].value_counts(sort=False).unstack()
data_cs_wy.plot(kind='bar', figsize=[10,6])
# Out:
# <AxesSubplot:xlabel='company_size'>
